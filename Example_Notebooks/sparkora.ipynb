# %% [markdown]
# ## Getting imports which are required

# %%
import pyspark.sql.functions as F
import pyspark.sql.types as T
import pandas as pd

# %% [markdown]
# ## Sparkora initialization

# %%
from Sparkora import Sparkora
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 3.2.0
#       /_/
#
# Using Python version 3.8.10 (default, Sep 28 2021 16:10:42)
# Spark context Web UI available at http://10.172.203.167:48830
# Spark context available as 'sc' (master = local[8], app id = local-1636888245786).
# SparkSession available as 'spark'.

# %% [markdown]
# ## Creating the spark sample dataframe

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Spratiher9/Sparkora/0.0.1/Sparkora/test_data.csv?token=AQWZISDC747WWFPLVRUCLXDBSDZIS")
df = spark.createDataFrame(df)

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>A</th><th>B</th><th>C</th><th>D</th><th>useless_feature</th></tr></thead><tbody><tr><td>1</td><td>2.0</td><td>0</td><td>left</td><td>1</td></tr><tr><td>4</td><td>null</td><td>1</td><td>right</td><td>1</td></tr><tr><td>7</td><td>8.0</td><td>2</td><td>left</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# # Demos from README

# %% [markdown]
# ## Configuring `Sparkora` with the sample data

# %%
sparkora = Sparkora()
sparkora.configure(output = 'A', data = df)

# %%
display(sparkora.data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>A</th><th>B</th><th>C</th><th>D</th><th>useless_feature</th></tr></thead><tbody><tr><td>1</td><td>2.0</td><td>0</td><td>left</td><td>1</td></tr><tr><td>4</td><td>null</td><td>1</td><td>right</td><td>1</td></tr><tr><td>7</td><td>8.0</td><td>2</td><td>left</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# ## Cleaning

# %%
d = [
  (1, 2, 100),
  (2, None, 200),
  (1, 6, None)
]
df = spark.createDataFrame(d, "_c0 int, _c1 int, _c2 int")

# %%
sparkora = Sparkora(output = '_c0', data = df)
sparkora.data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th></tr></thead><tbody><tr><td>1</td><td>2</td><td>100</td></tr><tr><td>2</td><td>null</td><td>200</td></tr><tr><td>1</td><td>6</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# ### Imputation

# %%
sparkora.impute_missing_values() # Imputation strategy can be passed here: mean, median, mode
sparkora.data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th></tr></thead><tbody><tr><td>1</td><td>2</td><td>100</td></tr><tr><td>2</td><td>4</td><td>200</td></tr><tr><td>1</td><td>6</td><td>150</td></tr></tbody></table></div>

# %% [markdown]
# ### Scaling the dataset

# %%
sparkora.scale_input_values()
sparkora.data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th></tr></thead><tbody><tr><td>1</td><td>0.0</td><td>0.0</td></tr><tr><td>2</td><td>0.5</td><td>1.0</td></tr><tr><td>1</td><td>1.0</td><td>0.5</td></tr></tbody></table></div>

# %% [markdown]
# ## Feature Selection & Extraction

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Spratiher9/Sparkora/0.0.1/Sparkora/test_data.csv?token=AQWZISDC747WWFPLVRUCLXDBSDZIS")
df = spark.createDataFrame(df)
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>A</th><th>B</th><th>C</th><th>D</th><th>useless_feature</th></tr></thead><tbody><tr><td>1</td><td>2.0</td><td>0</td><td>left</td><td>1</td></tr><tr><td>4</td><td>null</td><td>1</td><td>right</td><td>1</td></tr><tr><td>7</td><td>8.0</td><td>2</td><td>left</td><td>1</td></tr></tbody></table></div>

# %%
sparkora = Sparkora()
sparkora.configure(output = 'A', data = df)
sparkora.data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>A</th><th>B</th><th>C</th><th>D</th><th>useless_feature</th></tr></thead><tbody><tr><td>1</td><td>2.0</td><td>0</td><td>left</td><td>1</td></tr><tr><td>4</td><td>null</td><td>1</td><td>right</td><td>1</td></tr><tr><td>7</td><td>8.0</td><td>2</td><td>left</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# ### Removing feature

# %%
sparkora.remove_feature('useless_feature')
sparkora.data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>A</th><th>B</th><th>C</th><th>D</th></tr></thead><tbody><tr><td>1</td><td>2.0</td><td>0</td><td>left</td></tr><tr><td>4</td><td>null</td><td>1</td><td>right</td></tr><tr><td>7</td><td>8.0</td><td>2</td><td>left</td></tr></tbody></table></div>

# %% [markdown]
# ### Extracting an ordinal feature through one-hot encoding

# %%
sparkora.extract_ordinal_feature('D')
sparkora.data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>A</th><th>B</th><th>C</th><th>D=left</th><th>D=right</th></tr></thead><tbody><tr><td>1</td><td>2.0</td><td>0</td><td>1</td><td>0</td></tr><tr><td>4</td><td>null</td><td>1</td><td>0</td><td>1</td></tr><tr><td>7</td><td>8.0</td><td>2</td><td>1</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# ### Feature creation from existing feature(s)

# %% [markdown]
# #### single feature input

# %%
f_udf = F.udf(lambda x: x * 2, T.IntegerType())
sparkora.extract_feature('C', 'twoC', f_udf)
sparkora.data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>A</th><th>B</th><th>C</th><th>D=left</th><th>D=right</th><th>twoC</th></tr></thead><tbody><tr><td>1</td><td>2.0</td><td>0</td><td>1</td><td>0</td><td>0</td></tr><tr><td>4</td><td>null</td><td>1</td><td>0</td><td>1</td><td>2</td></tr><tr><td>7</td><td>8.0</td><td>2</td><td>1</td><td>0</td><td>4</td></tr></tbody></table></div>

# %% [markdown]
# #### multi feature input

# %%
f_udf = F.udf(lambda x,y: x * y, T.IntegerType())
sparkora.extract_feature(['C','A'], 'newC', f_udf)
sparkora.data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>A</th><th>B</th><th>C</th><th>D=left</th><th>D=right</th><th>twoC</th><th>newC</th></tr></thead><tbody><tr><td>1</td><td>2.0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td></tr><tr><td>4</td><td>null</td><td>1</td><td>0</td><td>1</td><td>2</td><td>4</td></tr><tr><td>7</td><td>8.0</td><td>2</td><td>1</td><td>0</td><td>4</td><td>14</td></tr></tbody></table></div>

# %% [markdown]
# ## Visualizing feature against output feature

# %%
sparkora.plot_feature('newC')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>newC</th><th>A</th></tr></thead><tbody><tr><td>0</td><td>1</td></tr><tr><td>4</td><td>4</td></tr><tr><td>14</td><td>7</td></tr></tbody></table></div>

# %% [markdown]
# ## Model Validation

# %%
sparkora.set_training_and_validation(0.8)

# %%
X = sparkora.training_data.select(sparkora.input_columns())
y = sparkora.training_data.select(sparkora.output)
X.display()
y.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>B</th><th>C</th><th>D=left</th><th>D=right</th><th>twoC</th><th>newC</th></tr></thead><tbody><tr><td>2.0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td></tr><tr><td>null</td><td>1</td><td>0</td><td>1</td><td>2</td><td>4</td></tr><tr><td>8.0</td><td>2</td><td>1</td><td>0</td><td>4</td><td>14</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>A</th></tr></thead><tbody><tr><td>1</td></tr><tr><td>4</td></tr><tr><td>7</td></tr></tbody></table></div>

# %%
X = sparkora.validating_data.select(sparkora.input_columns())
y = sparkora.validating_data.select(sparkora.output)
X.display()
y.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>B</th><th>C</th><th>D=left</th><th>D=right</th><th>twoC</th><th>newC</th></tr></thead><tbody></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>A</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## Versioning tranformations and states and logging the steps in each state

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Spratiher9/Sparkora/0.0.1/Sparkora/test_data.csv?token=AQWZISCH3QUFGHB653KPVBTBSD2XO")
df = spark.createDataFrame(df)
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>A</th><th>B</th><th>C</th><th>D</th><th>useless_feature</th></tr></thead><tbody><tr><td>1</td><td>2.0</td><td>0</td><td>left</td><td>1</td></tr><tr><td>4</td><td>null</td><td>1</td><td>right</td><td>1</td></tr><tr><td>7</td><td>8.0</td><td>2</td><td>left</td><td>1</td></tr></tbody></table></div>

# %%
sparkora = Sparkora()
sparkora.configure(output = 'A', data = df)
sparkora.data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>A</th><th>B</th><th>C</th><th>D</th><th>useless_feature</th></tr></thead><tbody><tr><td>1</td><td>2.0</td><td>0</td><td>left</td><td>1</td></tr><tr><td>4</td><td>null</td><td>1</td><td>right</td><td>1</td></tr><tr><td>7</td><td>8.0</td><td>2</td><td>left</td><td>1</td></tr></tbody></table></div>

# %%
sparkora.snapshot('initial_data')

# %%
sparkora.remove_feature('useless_feature')
sparkora.extract_ordinal_feature('D')
sparkora.impute_missing_values()
sparkora.scale_input_values()
sparkora.data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>A</th><th>B</th><th>C</th><th>D=left</th><th>D=right</th></tr></thead><tbody><tr><td>1</td><td>0.0</td><td>0</td><td>1.0</td><td>0.0</td></tr><tr><td>4</td><td>0.5</td><td>1</td><td>0.0</td><td>1.0</td></tr><tr><td>7</td><td>1.0</td><td>2</td><td>1.0</td><td>0.0</td></tr></tbody></table></div>

# %%
sparkora.logs
# Out:
# Out[39]: ["self.remove_feature('useless_feature')",
#  "self.extract_ordinal_feature('D')",
#  'self.impute_missing_values(mean)',
#  'self.scale_input_values()']

# %%
sparkora.snapshot('transform1')

# %%
sparkora.use_snapshot('initial_data')
sparkora.data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>A</th><th>B</th><th>C</th><th>D</th><th>useless_feature</th></tr></thead><tbody><tr><td>1</td><td>2.0</td><td>0</td><td>left</td><td>1</td></tr><tr><td>4</td><td>null</td><td>1</td><td>right</td><td>1</td></tr><tr><td>7</td><td>8.0</td><td>2</td><td>left</td><td>1</td></tr></tbody></table></div>

# %%
sparkora.logs
# Out:
# Out[42]: ["self.snapshot('initial_data')"]

# %%
sparkora.use_snapshot('transform1')
sparkora.data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>A</th><th>B</th><th>C</th><th>D=left</th><th>D=right</th></tr></thead><tbody><tr><td>1</td><td>0.0</td><td>0</td><td>1.0</td><td>0.0</td></tr><tr><td>4</td><td>0.5</td><td>1</td><td>0.0</td><td>1.0</td></tr><tr><td>7</td><td>1.0</td><td>2</td><td>1.0</td><td>0.0</td></tr></tbody></table></div>

# %%
sparkora.logs
# Out:
# Out[44]: ["self.remove_feature('useless_feature')",
#  "self.extract_ordinal_feature('D')",
#  'self.impute_missing_values(mean)',
#  'self.scale_input_values()',
#  "self.snapshot('transform1')"]

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
